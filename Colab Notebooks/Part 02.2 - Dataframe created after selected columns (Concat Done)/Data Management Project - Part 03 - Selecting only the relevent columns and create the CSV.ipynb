# %% [markdown]
# **mounting google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Getting required libs**

# %%
import csv
import pandas as pd
import numpy as np

# %% [markdown]
# **Dataset address**

# %%
SentimentsAddress = '/content/drive/MyDrive/Colab Notebooks/Data management Project/Data Management Project - Datafiles/Part 02.1 - Sentiments with polarities/SentimentsData515k.csv'
DatasetAddress = '/content/drive/MyDrive/Colab Notebooks/Data management Project/Data Management Project - Datafiles/Part 02 input - Dataset after Converting into CSV with correct structure/Part 02 input.csv'

OutputFileLocation = '/content/drive/MyDrive/Colab Notebooks/Data management Project/Data Management Project - Datafiles/Part 03 input - Dataset after adding sentiments and polarities/Dataset aftr adding sentiments and polarities.csv'

# %% [markdown]
# **reading the sentiments csv**

# %%
# Read the CSV file using pandas
SentimentsDF = pd.read_csv(SentimentsAddress)
number_of_training_cases = len(SentimentsDF.index)
display(SentimentsDF)
# Out:
#                           positive_sentence_column_Review  \
# 0        Only the park outside of the hotel was beauti...
# 1        No real complaints the hotel was great great ...
# 2        Location was good and staff were ok It is cut...
# 3        Great location in nice surroundings the bar a...
# 4         Amazing location and building Romantic setting
# ...                                                   ...
# 515733                                           location
# 515734      Breakfast was ok and we got earlier check in
# 515735                                                NaN
# 515736   The rooms are enormous and really comfortable...
# 515737                               staff was very kind
#
#        positive_sentence_column_Sentiment  \
# 0                                positive
# 1                                positive
# 2                                positive
# 3                                positive
# 4                                positive
# ...

# %% [markdown]
# **reading the data csv**

# %%
# Read the CSV file using pandas
DataDF = pd.read_csv(DatasetAddress)
number_of_training_cases = len(DataDF.index)
display(DataDF)
# Out:
# <ipython-input-51-79963556f20b>:2: DtypeWarning: Columns (15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   DataDF = pd.read_csv(DatasetAddress)
#                                      Hotel_Address_values  \
# 0       ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...
# 1       ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...
# 2       ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...
# 3       ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...
# 4       ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...
# ...                                                   ...
# 515733  'Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150...
# 515734  'Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150...
# 515735  'Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150...
# 515736  'Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150...
# 515737  'Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150...
#
#         Additional_Number_of_Scoring_values Review_Date_values  \
# ...

# %% [markdown]
# **Join together to create a dataframe**

# %%
print(np.array(SentimentsDF.columns))
print(np.array(DataDF.columns))
# Out:
# ['positive_sentence_column_Review' 'positive_sentence_column_Sentiment'
#  'positive_sentence_column_Positivity Percentage'
#  'positive_sentence_column_Negativity Percentage'
#  'negative_sentence_column_Review' 'negative_sentence_column_Sentiment'
#  'negative_sentence_column_Positivity Percentage'
#  'negative_sentence_column_Negativity Percentage']
# ['Hotel_Address_values' 'Additional_Number_of_Scoring_values'
#  'Review_Date_values' 'Average_Score_values' 'Hotel_Name_values'
#  'Reviewer_Nationality_values' 'Negative_Review'
#  'Review_Total_Negative_Word_Counts' 'Total_Number_of_Reviews'
#  'Positive_Review' 'Review_Total_Positive_Word_Counts'
#  'Total_Number_of_Reviews_Reviewer_Has_Given' 'Reviewer_Score'
#  'tag_column' 'days_since_review' 'latitude' 'longitude']

# %%
import pandas as pd

# Select columns from init dataset by name
dataset_selected_columns = DataDF[[
    'Hotel_Address_values',
    'Review_Date_values',
    'Average_Score_values',
    'Hotel_Name_values',
    'Reviewer_Nationality_values',
    'Negative_Review',
    'Review_Total_Negative_Word_Counts',
    'Total_Number_of_Reviews',
    'Positive_Review',
    'Review_Total_Positive_Word_Counts',
    'Total_Number_of_Reviews_Reviewer_Has_Given',
    'Reviewer_Score',
    'days_since_review',
    'latitude',
    'longitude',
    ]]



sentimentsd_selected_columns = SentimentsDF[np.array(SentimentsDF.columns)]

combined_df = pd.concat([dataset_selected_columns, sentimentsd_selected_columns], axis=1)

display(combined_df)
# Out:
#                                      Hotel_Address_values Review_Date_values  \
# 0       ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...           8/3/2017
# 1       ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...           8/3/2017
# 2       ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/31/2017
# 3       ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/31/2017
# 4       ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/24/2017
# ...                                                   ...                ...
# 515733  'Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150...          8/30/2015
# 515734  'Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150...          8/22/2015
# 515735  'Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150...          8/19/2015
# 515736  'Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150...          8/17/2015
# 515737  'Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150...           8/9/2015
#
# ...

# %%
SaveLocation = OutputFileLocation

# %%
# Define the file path in Google Drive
file_path = SaveLocation

# Save the DataFrame to a CSV file
combined_df.to_csv(file_path, index=False)

# Confirm the file was saved
print(f"File saved to {file_path}")

# %%
# Read the CSV file using pandas
SentimentsDF = pd.read_csv(SaveLocation)
number_of_training_cases = len(SentimentsDF.index)
display(SentimentsDF)
