# %% [markdown]
# **mounting google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Dataset address**

# %%
InputDataFile = '/content/drive/MyDrive/Colab Notebooks/Data management Project/Data Management Project - Datafiles/Part 04 input - sentiments, polarities, cleaned summaries added/sentiments, polarities, cleaned summaries added.csv'
ner_data_path = '/content/drive/MyDrive/Colab Notebooks/Data management Project/Data Management Project - Datafiles/Part 06 - NER added dataset/NER_added_result_CSV.csv'
finalized_dataset_path = '/content/drive/MyDrive/Colab Notebooks/Data management Project/Data Management Project - Datafiles/Part 06.1 - Original Dataset Summarized/compact-finalized-515k-hotel-dataset.csv'

# %% [markdown]
# ### **all the functions that are needed to do this step by step process**

# %%
import csv
import pandas as pd
import numpy as np

# %%
import pandas as pd

# Assuming your files are named 'ner_data.csv' and 'finalized_dataset.csv'
# Replace these with your actual file names

original_df = pd.read_csv(InputDataFile)

# Load NER Data
ner_data = pd.read_csv(ner_data_path)

# Load Finalized Dataset
finalized_dataset = pd.read_csv(finalized_dataset_path)

# Display information about the loaded DataFrames
print("NER Data:")
print(len(ner_data))

print("\nFinalized Dataset:")
print(len(finalized_dataset))
# Out:
# <ipython-input-4-3c405caf572a>:6: DtypeWarning: Columns (22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   original_df = pd.read_csv(InputDataFile)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-3c405caf572a> in <cell line: 12>()
#      10
#      11 # Load Finalized Dataset
# ---> 12 finalized_dataset = pd.read_csv(finalized_dataset_path)
#      13
#      14 # Display information about the loaded DataFrames
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
unique_ner_data_names = ner_data['Hotel_Name_values'].unique()
print(len(set(unique_ner_data_names)))
display(unique_ner_data_names)

original_compact_df = finalized_dataset['Hotel_Name_values'].unique()
print(len(original_compact_df))
display(original_compact_df)

# %%
# Assuming 'original_dataset' is your DataFrame
# Replace 'original_dataset' with your actual DataFrame name

# List of hotel names to drop
hotel_names_to_drop = {
    "'TownHouse Duomo'",
    "'11 Cadogan Gardens'",
    "'25hours Hotel beim MuseumsQuartier'",
    "'Timhotel Op ra Grands Magasins'",
    "'TownHouse 33'",
    "'1K Hotel'",
    "'TownHouse 12'"
}

# Filter and drop rows based on the specified hotel names
filtered_dataset = finalized_dataset[~finalized_dataset['Hotel_Name_values'].isin(hotel_names_to_drop)].copy()

# Display information about the filtered DataFrame
print(filtered_dataset.info())

# %%
unique_ner_data_names = ner_data['Hotel_Name_values'].unique()
print(len(set(unique_ner_data_names)))
display(ner_data.head(1))

original_compact_df = filtered_dataset['Hotel_Name_values'].unique()
print(len(original_compact_df))
display(original_df.head(1))

# %%
import pandas as pd

# Assuming 'original_df' and 'ner_data' are your DataFrames
# Replace them with your actual DataFrame names

# Merge the two DataFrames based on 'Hotel_Name_values'
merged_df = pd.merge(filtered_dataset, ner_data, on='Hotel_Name_values', how='left')

print(len(merged_df))
display(merged_df.iloc[40:81])

# %%
# output_path = '/content/drive/MyDrive/Colab Notebooks/Data management Project/Data Management Project - Datafiles/Part 06.2 - Original Dataset + Sentiments Summaries and NER/compact-finalized-515k-hotel-dataset with Sentiments Summaries and NER.csv'

# # Save the DataFrame to a CSV file
# merged_df.to_csv(output_path, index=False)

# print(f"DataFrame saved to: {output_path}")
