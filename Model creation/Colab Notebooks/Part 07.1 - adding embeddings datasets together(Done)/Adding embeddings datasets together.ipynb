# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
embedding01 = '/content/drive/MyDrive/Colab Notebooks/Data management Project/Data Management Project - Datafiles/Part 07 - Embeddings creation/embeddings1.csv'
embedding02 = '/content/drive/MyDrive/Colab Notebooks/Data management Project/Data Management Project - Datafiles/Part 07 - Embeddings creation/embeddings2.csv'

# %%
import csv
import pandas as pd
import numpy as np

# %%
# Read the CSV file using pandas
data1 = pd.read_csv(embedding01)
data2 = pd.read_csv(embedding02)

# number_of_training_cases = len(data.index)
print(len(data1))
print(len(data2))
display(data1.head(2))
# Out:
# <ipython-input-4-f4938d0ea0f7>:2: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1 = pd.read_csv(embedding01)
# 400000
# 115736
#    Sequence Hotel_Name_values  \
# 0         3     'Hotel Arena'
# 1         4     'Hotel Arena'
#
#                                 Hotel_Address_values Review_Date_values  \
# 0  ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/31/2017
# 1  ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/31/2017
#
#    Average_Score_values Reviewer_Nationality_values  \
# 0                   7.7               ' Australia '
# 1                   7.7          ' United Kingdom '
#
#   Negative_sentence_column_Sentiment  \
# 0                           negative
# 1                           negative
#
#    Negative_sentence_column_Positivity_Percentage  \
# 0                                            10.7
# 1                                            16.8
#
# ...

# %%
df01 = data1
df02 = data2

# %%
import pandas as pd

# Assuming you have loaded the CSV files into df01 and df02
# If not, you can load them using pd.read_csv('file_path')

# Concatenate the two DataFrames vertically
result_df = pd.concat([df01, df02], ignore_index=True)

# Write the result DataFrame to a new CSV file
# result_df.to_csv('result.csv', index=False)

# Display the memory usage of the DataFrame
print("Memory usage of the DataFrame:")
print(result_df.memory_usage(deep=True).sum() / (1024 * 1024), "MB")


# Display the resulting DataFrame
print(len(result_df))
display(result_df.head(3))
# Out:
# Memory usage of the DataFrame:
# 4222.840326309204 MB
# 515736
#    Sequence Hotel_Name_values  \
# 0         3     'Hotel Arena'
# 1         4     'Hotel Arena'
# 2         5     'Hotel Arena'
#
#                                 Hotel_Address_values Review_Date_values  \
# 0  ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/31/2017
# 1  ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/31/2017
# 2  ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/24/2017
#
#    Average_Score_values Reviewer_Nationality_values  \
# 0                   7.7               ' Australia '
# 1                   7.7          ' United Kingdom '
# 2                   7.7             ' New Zealand '
#
#   Negative_sentence_column_Sentiment  \
# 0                           negative
# 1                           negative
# 2                           positive
#
#    Negative_sentence_column_Positivity_Percentage  \
# 0                                            10.7
# ...

# %%
import pandas as pd

# Save the DataFrame to a CSV file
result_df.to_csv('/content/drive/MyDrive/Colab Notebooks/Data management Project/Data Management Project - Datafiles/Part 07 - Embeddings creation/compact_embeddings.csv', index=False)

# %%
# Read the CSV file using pandas
data3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data management Project/Data Management Project - Datafiles/Part 07 - Embeddings creation/compact_embeddings.csv', low_memory=False)


# number_of_training_cases = len(data.index)
print(len(data3))
display(data3.head(15))
# Out:
# 515736
#     Sequence Hotel_Name_values  \
# 0          3     'Hotel Arena'
# 1          4     'Hotel Arena'
# 2          5     'Hotel Arena'
# 3          6     'Hotel Arena'
# 4          7     'Hotel Arena'
# 5          8     'Hotel Arena'
# 6          9     'Hotel Arena'
# 7         10     'Hotel Arena'
# 8         11     'Hotel Arena'
# 9         12     'Hotel Arena'
# 10        13     'Hotel Arena'
# 11        14     'Hotel Arena'
# 12        15     'Hotel Arena'
# 13        16     'Hotel Arena'
# 14        17     'Hotel Arena'
#
#                                  Hotel_Address_values Review_Date_values  \
# 0   ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/31/2017
# 1   ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/31/2017
# 2   ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/24/2017
# 3   ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/24/2017
# 4   ' s Gravesandestraat 55 Oost 1092 AA Amsterdam...          7/17/2017
# ...
